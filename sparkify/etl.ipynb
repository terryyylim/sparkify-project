# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('./data/song_data')

# %%
filepath = song_files[0]

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  ARNTLGG11E2835DDB9              NaN                               NaN
#
#   artist_name   duration  num_songs             song_id  \
# 0         Clp  266.39628          1  SOUDSGM12AC9618304
#
#                                title  year
# 0  Insatiable (Instrumental Version)     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
def convert_dtype(row_entry):
    finalItem = []
    for item in row_entry:
        if type(item) != str:
            finalItem.append(item.item())
        else:
            finalItem.append(item)
    return finalItem

# %%
song_data = list(df[['song_id', 'title', 'artist_id', 'year', 'duration']].iloc[0].values)
song_data
# Out:
# ['SOUDSGM12AC9618304',
#  'Insatiable (Instrumental Version)',
#  'ARNTLGG11E2835DDB9',
#  0,
#  266.39627999999999]

# %%
song_data = convert_dtype(song_data)
song_data
# Out:
# ['SOUDSGM12AC9618304',
#  'Insatiable (Instrumental Version)',
#  'ARNTLGG11E2835DDB9',
#  0,
#  266.39628]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = list(df[['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']].iloc[0].values)
artist_data
# Out:
# ['ARNTLGG11E2835DDB9', 'Clp', '', nan, nan]

# %%
artist_data = convert_dtype(artist_data)
artist_data
# Out:
# ['ARNTLGG11E2835DDB9', 'Clp', '', nan, nan]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('./data/log_data')

# %%
filepath = log_files[0]

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#                              artist       auth firstName gender  \
# 0  Mitch Ryder & The Detroit Wheels  Logged In     Tegan      F
# 1                  The Spill Canvas  Logged In     Tegan      F
# 2                            Mogwai  Logged In     Tegan      F
# 3                              Spor  Logged In     Tegan      F
# 4                          DJ Dizzy  Logged In     Tegan      F
#
#    itemInSession lastName     length level                     location  \
# 0             65   Levine  205.03465  paid  Portland-South Portland, ME
# 1             66   Levine  358.03383  paid  Portland-South Portland, ME
# 2             67   Levine  571.19302  paid  Portland-South Portland, ME
# 3             68   Levine  380.34240  paid  Portland-South Portland, ME
# 4             69   Levine  221.15220  paid  Portland-South Portland, ME
#
#   method      page  registration  sessionId                            song  \
# 0    PUT  NextSong  1.540794e+12        992  Jenny Take A Ride (LP Version)
# 1    PUT  NextSong  1.540794e+12        992           The TIde (LP Version)
# 2    PUT  NextSong  1.540794e+12        992       Two Rights Make One Wrong
# 3    PUT  NextSong  1.540794e+12        992              Way Of The Samurai
# 4    PUT  NextSong  1.540794e+12        992                      Sexy Bitch
#
#    status             ts                                          userAgent  \
# 0     200  1543363215796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1543363420796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2     200  1543363778796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 3     200  1543364349796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1543364729796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId
# 0     80
# 1     80
# 2     80
# 3     80
# 4     80

# %%
df.columns
# Out:
# Index(['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
#        'length', 'level', 'location', 'method', 'page', 'registration',
#        'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'],
#       dtype='object')

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df[df['page'] == 'NextSong']
df.head()
# Out:
#                              artist       auth firstName gender  \
# 0  Mitch Ryder & The Detroit Wheels  Logged In     Tegan      F
# 1                  The Spill Canvas  Logged In     Tegan      F
# 2                            Mogwai  Logged In     Tegan      F
# 3                              Spor  Logged In     Tegan      F
# 4                          DJ Dizzy  Logged In     Tegan      F
#
#    itemInSession lastName     length level                     location  \
# 0             65   Levine  205.03465  paid  Portland-South Portland, ME
# 1             66   Levine  358.03383  paid  Portland-South Portland, ME
# 2             67   Levine  571.19302  paid  Portland-South Portland, ME
# 3             68   Levine  380.34240  paid  Portland-South Portland, ME
# 4             69   Levine  221.15220  paid  Portland-South Portland, ME
#
#   method      page  registration  sessionId                            song  \
# 0    PUT  NextSong  1.540794e+12        992  Jenny Take A Ride (LP Version)
# 1    PUT  NextSong  1.540794e+12        992           The TIde (LP Version)
# 2    PUT  NextSong  1.540794e+12        992       Two Rights Make One Wrong
# 3    PUT  NextSong  1.540794e+12        992              Way Of The Samurai
# 4    PUT  NextSong  1.540794e+12        992                      Sexy Bitch
#
#    status             ts                                          userAgent  \
# 0     200  1543363215796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1543363420796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2     200  1543363778796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 3     200  1543364349796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1543364729796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId
# 0     80
# 1     80
# 2     80
# 3     80
# 4     80

# %%
t = pd.to_datetime(df['ts'])
t.head()
# Out:
# 0   1970-01-01 00:25:43.363215796
# 1   1970-01-01 00:25:43.363420796
# 2   1970-01-01 00:25:43.363778796
# 3   1970-01-01 00:25:43.364349796
# 4   1970-01-01 00:25:43.364729796
# Name: ts, dtype: datetime64[ns]

# %%
time_data = (t, t.dt.hour, t.dt.day, t.dt.week, 
             t.dt.month, t.dt.year, t.dt.weekday)
column_labels = ('start_time', 'hour', 'day', 'week',
                 'month', 'year', 'weekday')

# %%
time_df = pd.DataFrame(dict(zip(column_labels, time_data)))
time_df.head()
# Out:
#                      start_time  hour  day  week  month  year  weekday
# 0 1970-01-01 00:25:43.363215796     0    1     1      1  1970        3
# 1 1970-01-01 00:25:43.363420796     0    1     1      1  1970        3
# 2 1970-01-01 00:25:43.363778796     0    1     1      1  1970        3
# 3 1970-01-01 00:25:43.364349796     0    1     1      1  1970        3
# 4 1970-01-01 00:25:43.364729796     0    1     1      1  1970        3

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId', 'firstName', 'lastName', 'gender', 'level']]
user_df.head()
# Out:
#   userId firstName lastName gender level
# 0     80     Tegan   Levine      F  paid
# 1     80     Tegan   Levine      F  paid
# 2     80     Tegan   Levine      F  paid
# 3     80     Tegan   Levine      F  paid
# 4     80     Tegan   Levine      F  paid

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in df.iterrows():
    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (index, pd.to_datetime(row['ts']), 
                     int(row.userId), row.level, songid,
                     artistid, row.sessionId, row.location, row.userAgent)
    
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()
# Out:
# Jenny Take A Ride (LP Version)
# Mitch Ryder & The Detroit Wheels
# 205.03465
# <class 'float'>
# 0
# 1970-01-01 00:25:43.363215796
# (0, Timestamp('1970-01-01 00:25:43.363215796'), 80, 'paid', None, None, 992, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# The TIde (LP Version)
# The Spill Canvas
# 358.03383
# <class 'float'>
# 1
# 1970-01-01 00:25:43.363420796
# (1, Timestamp('1970-01-01 00:25:43.363420796'), 80, 'paid', None, None, 992, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Two Rights Make One Wrong
# Mogwai
# 571.19302
# <class 'float'>
# 2
# 1970-01-01 00:25:43.363778796
# (2, Timestamp('1970-01-01 00:25:43.363778796'), 80, 'paid', None, None, 992, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Way Of The Samurai
# Spor
# 380.3424
# <class 'float'>
# 3
# 1970-01-01 00:25:43.364349796
# (3, Timestamp('1970-01-01 00:25:43.364349796'), 80, 'paid', None, None, 992, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Sexy Bitch
# DJ Dizzy
# 221.1522
# <class 'float'>
# 4
# 1970-01-01 00:25:43.364729796
# (4, Timestamp('1970-01-01 00:25:43.364729796'), 80, 'paid', None, None, 992, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Hurtful
# Erik Hassle
# 183.43138
# <class 'float'>
# 5
# 1970-01-01 00:25:43.364950796
# (5, Timestamp('1970-01-01 00:25:43.364950796'), 80, 'paid', None, None, 992, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Holdin' On Together
# Phoenix
# 207.15057
# <class 'float'>
# 13
# 1970-01-01 00:25:43.389321796
# (13, Timestamp('1970-01-01 00:25:43.389321796'), 92, 'free', None, None, 964, 'Palestine, TX', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Mardy Bum
# Arctic Monkeys
# 175.43791
# <class 'float'>
# 14
# 1970-01-01 00:25:43.389451796
# (14, Timestamp('1970-01-01 00:25:43.389451796'), 92, 'free', None, None, 964, 'Palestine, TX', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Burn For You
# tobyMac
# 229.69424
# <class 'float'>
# 15
# 1970-01-01 00:25:43.389593796
# (15, Timestamp('1970-01-01 00:25:43.389593796'), 74, 'free', None, None, 801, 'Youngstown-Warren-Boardman, OH-PA', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Who's Real
# Jadakiss / Swizz Beatz / OJ Da Juiceman
# 191.84281
# <class 'float'>
# 17
# 1970-01-01 00:25:43.389913796
# (17, Timestamp('1970-01-01 00:25:43.389913796'), 55, 'free', None, None, 996, 'Minneapolis-St. Paul-Bloomington, MN-WI', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Dog Days Are Over (Radio Edit)
# Florence + The Machine
# 219.66322
# <class 'float'>
# 18
# 1970-01-01 00:25:43.389920796
# (18, Timestamp('1970-01-01 00:25:43.389920796'), 40, 'free', None, None, 976, 'Oxnard-Thousand Oaks-Ventura, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Blue Orchid
# The White Stripes
# 160.31302
# <class 'float'>
# 19
# 1970-01-01 00:25:43.390182796
# (19, Timestamp('1970-01-01 00:25:43.390182796'), 40, 'free', None, None, 976, 'Oxnard-Thousand Oaks-Ventura, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# You (w/o Organ Version)
# Plus One
# 231.8624
# <class 'float'>
# 20
# 1970-01-01 00:25:43.390381796
# (20, Timestamp('1970-01-01 00:25:43.390381796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Mr. Jones
# Counting Crows
# 272.79628
# <class 'float'>
# 21
# 1970-01-01 00:25:43.390549796
# (21, Timestamp('1970-01-01 00:25:43.390549796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# A Different City
# Pickin' On Series
# 199.41832
# <class 'float'>
# 22
# 1970-01-01 00:25:43.390748796
# (22, Timestamp('1970-01-01 00:25:43.390748796'), 9, 'free', None, None, 922, 'Eureka-Arcata-Fortuna, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Hailie's Song
# Eminem
# 320.83546
# <class 'float'>
# 23
# 1970-01-01 00:25:43.390901796
# (23, Timestamp('1970-01-01 00:25:43.390901796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Wild Child
# Heart
# 270.18404
# <class 'float'>
# 24
# 1970-01-01 00:25:43.391139796
# (24, Timestamp('1970-01-01 00:25:43.391139796'), 9, 'free', None, None, 922, 'Eureka-Arcata-Fortuna, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# La Vida Pasa
# Sergio Dalma
# 269.45261
# <class 'float'>
# 29
# 1970-01-01 00:25:43.392152796
# (29, Timestamp('1970-01-01 00:25:43.392152796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# The Interview
# AFI
# 256.86159
# <class 'float'>
# 30
# 1970-01-01 00:25:43.392326796
# (30, Timestamp('1970-01-01 00:25:43.392326796'), 9, 'free', None, None, 922, 'Eureka-Arcata-Fortuna, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# This Body Pays The Bill$
# Four Year Strong
# 199.88853
# <class 'float'>
# 31
# 1970-01-01 00:25:43.392580796
# (31, Timestamp('1970-01-01 00:25:43.392580796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Undercover Martyn
# Two Door Cinema Club
# 168.09751
# <class 'float'>
# 32
# 1970-01-01 00:25:43.392802796
# (32, Timestamp('1970-01-01 00:25:43.392802796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Rendezvous
# Jim Brickman;Herb Alpert;Bruce Upchurch
# 199.54893
# <class 'float'>
# 33
# 1970-01-01 00:25:43.393040796
# (33, Timestamp('1970-01-01 00:25:43.393040796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Le Courage Des Oiseaux
# Dominique A
# 153.20771
# <class 'float'>
# 34
# 1970-01-01 00:25:43.393137796
# (34, Timestamp('1970-01-01 00:25:43.393137796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Voices
# Pure Ecstasy
# 238.94159
# <class 'float'>
# 35
# 1970-01-01 00:25:43.393393796
# (35, Timestamp('1970-01-01 00:25:43.393393796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Bailala
# Juanes
# 211.77424
# <class 'float'>
# 37
# 1970-01-01 00:25:43.393866796
# (37, Timestamp('1970-01-01 00:25:43.393866796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Stacy's Mom
# Fountains Of Wayne
# 197.40689
# <class 'float'>
# 38
# 1970-01-01 00:25:43.394066796
# (38, Timestamp('1970-01-01 00:25:43.394066796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Unite (2009 Digital Remaster)
# Beastie Boys
# 211.722
# <class 'float'>
# 39
# 1970-01-01 00:25:43.394272796
# (39, Timestamp('1970-01-01 00:25:43.394272796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Tighten Up
# The Black Keys
# 211.01669
# <class 'float'>
# 40
# 1970-01-01 00:25:43.394526796
# (40, Timestamp('1970-01-01 00:25:43.394526796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Yes
# LMFAO
# 183.74485
# <class 'float'>
# 41
# 1970-01-01 00:25:43.394747796
# (41, Timestamp('1970-01-01 00:25:43.394747796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Sorrow (1997 Digital Remaster)
# David Bowie
# 174.41914
# <class 'float'>
# 42
# 1970-01-01 00:25:43.395089796
# (42, Timestamp('1970-01-01 00:25:43.395089796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# The Ascent Of Stan
# Ben Folds
# 254.17098
# <class 'float'>
# 43
# 1970-01-01 00:25:43.395302796
# (43, Timestamp('1970-01-01 00:25:43.395302796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# One Way Or Another
# Kate Voegele
# 222.64118
# <class 'float'>
# 44
# 1970-01-01 00:25:43.395534796
# (44, Timestamp('1970-01-01 00:25:43.395534796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Jefferson Aeroplane [Demo]
# Relient K
# 238.94159
# <class 'float'>
# 45
# 1970-01-01 00:25:43.395706796
# (45, Timestamp('1970-01-01 00:25:43.395706796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Yr Broom (Cd)
# Someone Still Loves You Boris Yeltsin
# 97.35791
# <class 'float'>
# 46
# 1970-01-01 00:25:43.395917796
# (46, Timestamp('1970-01-01 00:25:43.395917796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Suena ("Some Day" end title song "The Hunchback of Notre Dame")
# Luis Miguel
# 256.13016
# <class 'float'>
# 47
# 1970-01-01 00:25:43.395987796
# (47, Timestamp('1970-01-01 00:25:43.395987796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Por quererte
# Efecto Mariposa
# 254.37995
# <class 'float'>
# 48
# 1970-01-01 00:25:43.396088796
# (48, Timestamp('1970-01-01 00:25:43.396088796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# A Starting Point
# Dif Juz
# 219.16689
# <class 'float'>
# 49
# 1970-01-01 00:25:43.396255796
# (49, Timestamp('1970-01-01 00:25:43.396255796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Something (Album Version)
# Jaci Velasquez
# 200.95955
# <class 'float'>
# 52
# 1970-01-01 00:25:43.396651796
# (52, Timestamp('1970-01-01 00:25:43.396651796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Falling Forward
# The Methadones
# 206.39302
# <class 'float'>
# 53
# 1970-01-01 00:25:43.396822796
# (53, Timestamp('1970-01-01 00:25:43.396822796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# It's Not What
# SKOLD vs. KMFDM
# 254.4322
# <class 'float'>
# 54
# 1970-01-01 00:25:43.396997796
# (54, Timestamp('1970-01-01 00:25:43.396997796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Broken
# Leatherface
# 221.09995
# <class 'float'>
# 55
# 1970-01-01 00:25:43.397114796
# (55, Timestamp('1970-01-01 00:25:43.397114796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Suavemente
# Scooter
# 342.04689
# <class 'float'>
# 56
# 1970-01-01 00:25:43.397176796
# (56, Timestamp('1970-01-01 00:25:43.397176796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Run The Show (featuring Busta Rhymes)
# Kat DeLuna featuring Busta Rhymes
# 213.13261
# <class 'float'>
# 58
# 1970-01-01 00:25:43.397317796
# (58, Timestamp('1970-01-01 00:25:43.397317796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Hero/Heroine
# Boys Like Girls
# 232.22812
# <class 'float'>
# 59
# 1970-01-01 00:25:43.397517796
# (59, Timestamp('1970-01-01 00:25:43.397517796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Monkey Man
# Amy Winehouse
# 172.82567
# <class 'float'>
# 60
# 1970-01-01 00:25:43.397541796
# (60, Timestamp('1970-01-01 00:25:43.397541796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# I.O.U. Me
# Bebe And Cece Winans
# 281.59955
# <class 'float'>
# 61
# 1970-01-01 00:25:43.397687796
# (61, Timestamp('1970-01-01 00:25:43.397687796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Gimme Sympathy
# Metric
# 171.25832
# <class 'float'>
# 63
# 1970-01-01 00:25:43.397770796
# (63, Timestamp('1970-01-01 00:25:43.397770796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Yellow
# Coldplay
# 268.38159
# <class 'float'>
# 64
# 1970-01-01 00:25:43.397807796
# (64, Timestamp('1970-01-01 00:25:43.397807796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Some Kind Of Monster
# Metallica
# 505.52118
# <class 'float'>
# 65
# 1970-01-01 00:25:43.397941796
# (65, Timestamp('1970-01-01 00:25:43.397941796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# There's A Fire
# Ok Go
# 230.29506
# <class 'float'>
# 66
# 1970-01-01 00:25:43.398004796
# (66, Timestamp('1970-01-01 00:25:43.398004796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Reisende Freunde
# Die Mooskirchner
# 166.922
# <class 'float'>
# 67
# 1970-01-01 00:25:43.398194796
# (67, Timestamp('1970-01-01 00:25:43.398194796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Say
# Method Man
# 229.53751
# <class 'float'>
# 68
# 1970-01-01 00:25:43.398198796
# (68, Timestamp('1970-01-01 00:25:43.398198796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Slip
# Deadmau5
# 463.04608
# <class 'float'>
# 69
# 1970-01-01 00:25:43.398383796
# (69, Timestamp('1970-01-01 00:25:43.398383796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Tush
# ZZ Top
# 354.29832
# <class 'float'>
# 71
# 1970-01-01 00:25:43.398615796
# (71, Timestamp('1970-01-01 00:25:43.398615796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Dead & Bloated (LP Version)
# Stone Temple Pilots
# 310.25587
# <class 'float'>
# 72
# 1970-01-01 00:25:43.398718796
# (72, Timestamp('1970-01-01 00:25:43.398718796'), 50, 'free', None, None, 988, 'New Haven-Milford, CT', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# cherish (the night_ the life_ the moon)
# Jazzamor
# 195.5522
# <class 'float'>
# 73
# 1970-01-01 00:25:43.398807796
# (73, Timestamp('1970-01-01 00:25:43.398807796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Carry On
# The Cranberries
# 141.50485
# <class 'float'>
# 74
# 1970-01-01 00:25:43.398962796
# (74, Timestamp('1970-01-01 00:25:43.398962796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Brokenheartsville
# Joe Nichols
# 232.14975
# <class 'float'>
# 75
# 1970-01-01 00:25:43.399177796
# (75, Timestamp('1970-01-01 00:25:43.399177796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Spotlight
# Mutemath
# 200.51546
# <class 'float'>
# 76
# 1970-01-01 00:25:43.399212796
# (76, Timestamp('1970-01-01 00:25:43.399212796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Mirror_ Mirror
# Whiskeytown
# 197.77261
# <class 'float'>
# 77
# 1970-01-01 00:25:43.399361796
# (77, Timestamp('1970-01-01 00:25:43.399361796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Gettin' It
# Chingy
# 266.34404
# <class 'float'>
# 78
# 1970-01-01 00:25:43.399408796
# (78, Timestamp('1970-01-01 00:25:43.399408796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Frisch und g'sund
# Die Mooskirchner
# 169.29914
# <class 'float'>
# 80
# 1970-01-01 00:25:43.399822796
# (80, Timestamp('1970-01-01 00:25:43.399822796'), 76, 'free', None, None, 921, 'Seattle-Tacoma-Bellevue, WA', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Telephone Love (LP Version)
# Keith Sweat
# 56.05832
# <class 'float'>
# 81
# 1970-01-01 00:25:43.400076796
# (81, Timestamp('1970-01-01 00:25:43.400076796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Moonlight
# Digitalism
# 171.96363
# <class 'float'>
# 82
# 1970-01-01 00:25:43.400353796
# (82, Timestamp('1970-01-01 00:25:43.400353796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Stacy's Mom
# Fountains Of Wayne
# 197.40689
# <class 'float'>
# 83
# 1970-01-01 00:25:43.400655796
# (83, Timestamp('1970-01-01 00:25:43.400655796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Clock
# Simian Mobile Disco
# 257.35791
# <class 'float'>
# 84
# 1970-01-01 00:25:43.400873796
# (84, Timestamp('1970-01-01 00:25:43.400873796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# State Of Fear
# Useless I.D.
# 190.98077
# <class 'float'>
# 85
# 1970-01-01 00:25:43.401585796
# (85, Timestamp('1970-01-01 00:25:43.401585796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Foolish
# Ashanti
# 232.25424
# <class 'float'>
# 86
# 1970-01-01 00:25:43.401852796
# (86, Timestamp('1970-01-01 00:25:43.401852796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Genom tunna tyger
# Markus KrunegÃÂ¥rd
# 185.5473
# <class 'float'>
# 87
# 1970-01-01 00:25:43.402005796
# (87, Timestamp('1970-01-01 00:25:43.402005796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Rebel Yell (Acoustic Live on KROQ) (2001 Digital Remaster)
# Billy Idol
# 335.38567
# <class 'float'>
# 88
# 1970-01-01 00:25:43.402126796
# (88, Timestamp('1970-01-01 00:25:43.402126796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Hasta Manana
# Abba
# 189.962
# <class 'float'>
# 89
# 1970-01-01 00:25:43.402237796
# (89, Timestamp('1970-01-01 00:25:43.402237796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Lights Out
# Santogold
# 192.46975
# <class 'float'>
# 90
# 1970-01-01 00:25:43.402360796
# (90, Timestamp('1970-01-01 00:25:43.402360796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Come Back To Bed
# John Mayer
# 494.34077
# <class 'float'>
# 91
# 1970-01-01 00:25:43.402568796
# (91, Timestamp('1970-01-01 00:25:43.402568796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Burned Alive By Time
# Evergreen Terrace
# 155.92444
# <class 'float'>
# 92
# 1970-01-01 00:25:43.402787796
# (92, Timestamp('1970-01-01 00:25:43.402787796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Ghosts (Toxic Avenger Mix)
# Ladytron
# 215.11791
# <class 'float'>
# 94
# 1970-01-01 00:25:43.403172796
# (94, Timestamp('1970-01-01 00:25:43.403172796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# My Moon My Man
# Feist
# 184.94649
# <class 'float'>
# 95
# 1970-01-01 00:25:43.403344796
# (95, Timestamp('1970-01-01 00:25:43.403344796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Young
# Hollywood Undead
# 196.41424
# <class 'float'>
# 96
# 1970-01-01 00:25:43.403434796
# (96, Timestamp('1970-01-01 00:25:43.403434796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Towards And Against
# Amorphis
# 299.07546
# <class 'float'>
# 97
# 1970-01-01 00:25:43.403707796
# (97, Timestamp('1970-01-01 00:25:43.403707796'), 58, 'paid', None, None, 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Bodies
# Drowning Pool
# 201.63873
# <class 'float'>
# 98
# 1970-01-01 00:25:43.403879796
# (98, Timestamp('1970-01-01 00:25:43.403879796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Living In Love
# I-Wayne
# 213.86404
# <class 'float'>
# 99
# 1970-01-01 00:25:43.404138796
# (99, Timestamp('1970-01-01 00:25:43.404138796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Sour Times
# Portishead
# 254.04036
# <class 'float'>
# 101
# 1970-01-01 00:25:43.404642796
# (101, Timestamp('1970-01-01 00:25:43.404642796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner
# 277.15873
# <class 'float'>
# 102
# 1970-01-01 00:25:43.404874796
# (102, Timestamp('1970-01-01 00:25:43.404874796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# The Gift
# Angels and Airwaves
# 302.05342
# <class 'float'>
# 104
# 1970-01-01 00:25:43.405300796
# (104, Timestamp('1970-01-01 00:25:43.405300796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# 16 Candles
# The Crests
# 182.88281
# <class 'float'>
# 105
# 1970-01-01 00:25:43.405421796
# (105, Timestamp('1970-01-01 00:25:43.405421796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# It's A Sin (2001 Digital Remaster)
# Pet Shop Boys
# 299.02322
# <class 'float'>
# 111
# 1970-01-01 00:25:43.406819796
# (111, Timestamp('1970-01-01 00:25:43.406819796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# The Only Exception (Album Version)
# Paramore
# 267.65016
# <class 'float'>
# 113
# 1970-01-01 00:25:43.407201796
# (113, Timestamp('1970-01-01 00:25:43.407201796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Promises Like Pie-Crust (Album)
# Carla Bruni
# 153.20771
# <class 'float'>
# 114
# 1970-01-01 00:25:43.407267796
# (114, Timestamp('1970-01-01 00:25:43.407267796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Comatose (Comes Alive Version)
# Skillet
# 232.46322
# <class 'float'>
# 115
# 1970-01-01 00:25:43.407349796
# (115, Timestamp('1970-01-01 00:25:43.407349796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Bloodletting (The Vampire Song)
# Concrete Blonde
# 270.28853
# <class 'float'>
# 116
# 1970-01-01 00:25:43.407451796
# (116, Timestamp('1970-01-01 00:25:43.407451796'), 100, 'free', None, None, 942, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Parabienes Al Reves
# Violeta Parra
# 123.34975
# <class 'float'>
# 117
# 1970-01-01 00:25:43.407513796
# (117, Timestamp('1970-01-01 00:25:43.407513796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Chiron Beta Prime
# Jonathan Coulton
# 208.03873
# <class 'float'>
# 118
# 1970-01-01 00:25:43.407666796
# (118, Timestamp('1970-01-01 00:25:43.407666796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Come As You Are
# Nirvana
# 219.08853
# <class 'float'>
# 119
# 1970-01-01 00:25:43.407905796
# (119, Timestamp('1970-01-01 00:25:43.407905796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Broken_ Beat & Scarred
# Metallica
# 385.43628
# <class 'float'>
# 120
# 1970-01-01 00:25:43.408162796
# (120, Timestamp('1970-01-01 00:25:43.408162796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Someone To Save You
# OneRepublic
# 252.70812
# <class 'float'>
# 121
# 1970-01-01 00:25:43.408284796
# (121, Timestamp('1970-01-01 00:25:43.408284796'), 101, 'free', None, None, 955, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Poison
# Bell Biv DeVoe
# 262.00771
# <class 'float'>
# 122
# 1970-01-01 00:25:43.408558796
# (122, Timestamp('1970-01-01 00:25:43.408558796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Ugly Girls
# Kalle Baah
# 273.76281
# <class 'float'>
# 123
# 1970-01-01 00:25:43.408791796
# (123, Timestamp('1970-01-01 00:25:43.408791796'), 101, 'free', None, None, 955, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Trouble
# Coldplay
# 273.47546
# <class 'float'>
# 124
# 1970-01-01 00:25:43.409129796
# (124, Timestamp('1970-01-01 00:25:43.409129796'), 82, 'paid', None, None, 140, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# The List
# Metric
# 172.69506
# <class 'float'>
# 125
# 1970-01-01 00:25:43.409367796
# ...
# <class 'str'>
# Take It There
# The Roots / Wadud Ahmad
# 170.70975
# <class 'float'>
# 333
# 1970-01-01 00:25:43.446059796
# (333, Timestamp('1970-01-01 00:25:43.446059796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Shiver
# Coldplay
# 298.762
# <class 'float'>
# 334
# 1970-01-01 00:25:43.446235796
# (334, Timestamp('1970-01-01 00:25:43.446235796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Tribulations
# LCD Soundsystem
# 298.89261
# <class 'float'>
# 335
# 1970-01-01 00:25:43.446294796
# (335, Timestamp('1970-01-01 00:25:43.446294796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Luckie Street
# Cartel
# 223.79057
# <class 'float'>
# 336
# 1970-01-01 00:25:43.446495796
# (336, Timestamp('1970-01-01 00:25:43.446495796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Bella's Lullaby (Twilight Soundtrack Version)
# Carter Burwell
# 138.70975
# <class 'float'>
# 337
# 1970-01-01 00:25:43.446521796
# (337, Timestamp('1970-01-01 00:25:43.446521796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Fireflies
# The Coral
# 237.63546
# <class 'float'>
# 338
# 1970-01-01 00:25:43.446701796
# (338, Timestamp('1970-01-01 00:25:43.446701796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Rat Fink
# The Misfits
# 112.06485
# <class 'float'>
# 339
# 1970-01-01 00:25:43.446717796
# (339, Timestamp('1970-01-01 00:25:43.446717796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Inaudible Melodies
# Jack Johnson
# 215.40526
# <class 'float'>
# 340
# 1970-01-01 00:25:43.446899796
# (340, Timestamp('1970-01-01 00:25:43.446899796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# In Space
# RÃÂ¶yksopp
# 210.99057
# <class 'float'>
# 341
# 1970-01-01 00:25:43.446955796
# (341, Timestamp('1970-01-01 00:25:43.446955796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Where The Wild Things Were
# Sounds from the Ground
# 458.31791
# <class 'float'>
# 342
# 1970-01-01 00:25:43.447095796
# (342, Timestamp('1970-01-01 00:25:43.447095796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Ladies (Dub) (2005 Digital Remaster)
# Mantronix
# 353.64526
# <class 'float'>
# 343
# 1970-01-01 00:25:43.447199796
# (343, Timestamp('1970-01-01 00:25:43.447199796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# I Will Follow You into the Dark (Album Version)
# Death Cab for Cutie
# 189.3873
# <class 'float'>
# 344
# 1970-01-01 00:25:43.447319796
# (344, Timestamp('1970-01-01 00:25:43.447319796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Last Night On Earth [feat. Green Day & The Cast Of American Idiot] (Album Version)
# Green Day
# 256.02567
# <class 'float'>
# 345
# 1970-01-01 00:25:43.447377796
# (345, Timestamp('1970-01-01 00:25:43.447377796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Across The Sky
# Scooter
# 347.19302
# <class 'float'>
# 346
# 1970-01-01 00:25:43.447542796
# (346, Timestamp('1970-01-01 00:25:43.447542796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Ich trau' mich nicht
# Bodo Wartke
# 377.41669
# <class 'float'>
# 348
# 1970-01-01 00:25:43.447730796
# (348, Timestamp('1970-01-01 00:25:43.447730796'), 26, 'free', None, None, 1039, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Witch Doctor
# Chris Classic
# 180.61016
# <class 'float'>
# 349
# 1970-01-01 00:25:43.447879796
# (349, Timestamp('1970-01-01 00:25:43.447879796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Travelin' Band
# Creedence Clearwater Revival
# 135.52281
# <class 'float'>
# 350
# 1970-01-01 00:25:43.447973796
# (350, Timestamp('1970-01-01 00:25:43.447973796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Shots
# LMFAO / Lil Jon
# 222.17098
# <class 'float'>
# 351
# 1970-01-01 00:25:43.448083796
# (351, Timestamp('1970-01-01 00:25:43.448083796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Love Resurrection
# Alison Moyet
# 230.00771
# <class 'float'>
# 352
# 1970-01-01 00:25:43.448305796
# (352, Timestamp('1970-01-01 00:25:43.448305796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Colors
# Amos Lee
# 160.49587
# <class 'float'>
# 353
# 1970-01-01 00:25:43.448541796
# (353, Timestamp('1970-01-01 00:25:43.448541796'), 26, 'free', None, None, 1039, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Smile
# Los Dynamite
# 253.1522
# <class 'float'>
# 354
# 1970-01-01 00:25:43.448570796
# (354, Timestamp('1970-01-01 00:25:43.448570796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Rocker
# Alter Ego
# 285.09995
# <class 'float'>
# 355
# 1970-01-01 00:25:43.448795796
# (355, Timestamp('1970-01-01 00:25:43.448795796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Brave The Elements
# Colossal
# 206.99383
# <class 'float'>
# 356
# 1970-01-01 00:25:43.448809796
# (356, Timestamp('1970-01-01 00:25:43.448809796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Over Now
# Alice In Chains
# 423.6273
# <class 'float'>
# 357
# 1970-01-01 00:25:43.448929796
# (357, Timestamp('1970-01-01 00:25:43.448929796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Rest My Chemistry
# Interpol
# 299.72853
# <class 'float'>
# 358
# 1970-01-01 00:25:43.449016796
# (358, Timestamp('1970-01-01 00:25:43.449016796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Cover Me
# BjÃÂ¶rk
# 185.46893
# <class 'float'>
# 359
# 1970-01-01 00:25:43.449264796
# (359, Timestamp('1970-01-01 00:25:43.449264796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Girls
# Death In Vegas
# 270.23628
# <class 'float'>
# 360
# 1970-01-01 00:25:43.449294796
# (360, Timestamp('1970-01-01 00:25:43.449294796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Sehr kosmisch
# Harmonia
# 655.77751
# <class 'float'>
# 361
# 1970-01-01 00:25:43.449413796
# (361, Timestamp('1970-01-01 00:25:43.449413796'), 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# Alley Oop (Live)
# George Thorogood And The Destroyers
# 238.34077
# <class 'float'>
# 362
# 1970-01-01 00:25:43.449470796
# (362, Timestamp('1970-01-01 00:25:43.449470796'), 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# <class 'int'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'int'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# A Beautiful Mess (Album Version)
# Jason Mraz
# 337.97179
# <class 'float'>
# 363
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-79a3cd211588> in <module>()
#       5     print(type(row.length))
#       6     print(index)
# ----> 7     print(time_df['start_time'].iloc[index])
#       8     # get songid and artistid from song and artist tables
#       9     cur.execute(song_select, (row.song, row.artist, row.length))
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
